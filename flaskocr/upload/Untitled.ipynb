# %%
import cv2
import pandas as pd

# %%
from wand.image import Image

# %%
# %matplotlib notebook

# %%
df = pd.read_csv('test.tsv', delimiter= '\t')
img = cv2.imread('bloodtest.jpg')
for i in range(len(df)-1):
    (x, y, w, h) = (df['left'][i], df['top'][i], df['width'][i], df['height'][i])
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

plt.imshow(img,'brg')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.imread('bloodtest.jpg')
# Out:
# array([[[219, 204, 185],
#         [220, 205, 186],
#         [219, 204, 185],
#         ...,
#         [215, 198, 180],
#         [213, 196, 178],
#         [212, 195, 177]],
#
#        [[220, 205, 186],
#         [220, 205, 186],
#         [220, 205, 186],
#         ...,
#         [215, 198, 180],
#         [214, 197, 179],
#         [214, 197, 179]],
#
#        [[222, 207, 188],
#         [221, 206, 187],
#         [220, 205, 186],
#         ...,
#         [214, 197, 179],
#         [216, 199, 181],
#         [218, 201, 183]],
#
#        ...,
#
#        [[200, 187, 171],
#         [197, 184, 168],
#         [199, 183, 168],
#         ...,
#         [153, 143, 134],
#         [145, 135, 126],
#         [151, 141, 132]],
#
#        [[200, 187, 171],
#         [195, 182, 166],
#         [197, 181, 166],
#         ...,
#         [149, 139, 130],
#         [147, 137, 128],
#         [157, 147, 138]],
#
#        [[199, 186, 170],
#         [194, 181, 165],
#         [195, 179, 164],
#         ...,
#         [142, 132, 123],
#         [150, 140, 131],
#         [164, 154, 145]]], dtype=uint8)
