# %%
import os
print(os.getcwd())
# Out:
# /Users/jingjinglin/Machine_Learning/Siuvo2019SummerIntern/Tesseract-OCR/lab_test_result

# %%
import img2pdf

# %%
with open("labtest1.pdf","wb") as f:
    f.write(img2pdf.convert('labtest1_alphaoff.png'))

# %%
import camelot

# %%
tables = camelot.read_pdf('table.pdf', flavor='stream')

# %%
tables.export('foo.csv', f='csv', compress=False)

# %%
tables
# Out:
# <TableList n=1>

# %%
len(tables)
# Out:
# 1

# %%
import pandas as pd

# %%
df = pd.read_csv('foo-page-1-table-1.csv', header=5)

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 3      结 果 Unnamed: 5  \
# 0         NaN        NaN        NaN           NaN      NaN        NaN
# 1         NaN        NaN        NaN           NaN      NaN        NaN
# 2         NaN        NaN        1 D      白细 胞 数 目      NaN        NaN
# 3         NaN        NaN        NaN           NaN    7. 43        NaN
# 4         NaN        NaN        NaN           NaN      NaN        NaN
# 5         NaN        NaN        NaN           NaN      NaN        NaN
# 6         NaN        NaN    2\nNEU#       中性数 细 胞      NaN        NaN
# 7         NaN        NaN        NaN           NaN    3. 54        NaN
# 8         NaN        NaN        NaN           NaN      NaN        NaN
# 9         NaN        NaN        NaN           NaN      NaN        NaN
# 10        NaN        NaN        NaN           NaN      NaN        NaN
# 11        NaN        NaN    3\nLym#   淋 巴 细 胞 数 目      NaN        NaN
# 12        NaN        NaN        NaN           NaN     3.37        NaN
# 13        NaN        NaN        NaN           NaN      NaN        NaN
# 14        NaN        NaN        NaN           NaN      NaN        NaN
# 15        NaN        NaN        NaN           NaN      NaN        NaN
# 16          ˇ        NaN   《\n_Mon#          单核 细      NaN        NaN
# 17        NaN        NaN        NaN           数 目    0. 36        NaN
# 18        NaN        NaN        NaN           NaN      NaN        NaN
# 19        NaN        NaN        NaN           NaN      NaN        NaN
# 20        NaN        NaN        NaN           NaN      NaN        NaN
# 21        NaN        NaN        NaN           NaN      NaN        NaN
# 22        NaN        NaN    5\nEos#           NaN      NaN        NaN
# 23        NaN        NaN        NaN    啤酸性粒细 胞\n目     0 11        NaN
# 24        NaN        NaN        NaN           NaN      NaN        NaN
# 25        NaN        NaN        NaN           NaN      NaN        NaN
# 26        NaN        NaN        NaN           NaN      NaN        NaN
# 27        NaN          *    6\nBas#        嗉 碱性粒细      NaN        NaN
# 28        NaN        NaN        NaN           数 目    0. 05        NaN
# 29        NaN        NaN        NaN           NaN      NaN        NaN
# ..        ...        ...        ...           ...      ...        ...
# 37        NaN        NaN        NaN           NaN      NaN        NaN
# 38        NaN        NaN  ,8\nLymw%           NaN      NaN        NaN
# 39        NaN        NaN        NaN     淋 巴细胞 百分比    45.30          f
# 40        NaN        NaN        NaN           NaN      NaN        NaN
# 41        NaN        NaN        NaN           NaN      NaN        NaN
# 42        NaN        NaN        NaN           NaN      NaN        NaN
# 43        NaN        NaN    9\nMon%       单核细胞百分比      NaN        NaN
# 44        NaN        NaN        NaN           NaN    4. 90        NaN
# 45        NaN        NaN        NaN           NaN      NaN        NaN
# 46        NaN        NaN        NaN           NaN      NaN        NaN
# 47        NaN        NaN        NaN           NaN      NaN        NaN
# 48        NaN        NaN    10 Eos%           NaN      NaN        NaN
# 49        NaN        NaN        NaN  啸 酸性粒细 胞 百分比    1. 40        NaN
# 50        NaN        NaN        NaN           NaN      NaN        NaN
# 51        NaN        NaN        NaN           NaN      NaN        NaN
# 52        NaN        NaN        NaN           NaN      NaN        NaN
# 53        NaN        NaN    L1 Bas%           NaN      NaN        NaN
# 54        NaN        NaN        NaN     嗜碱性粒细胞百 分      0.7        NaN
# 55        NaN        NaN        NaN           NaN      NaN        NaN
# 56        NaN        NaN    12 RBC.         红细 胞数      NaN        NaN
# 57        NaN        NaN        NaN           NaN    4. 61        NaN
# 58        NaN        NaN        NaN           NaN      NaN        NaN
# 59        NaN        NaN     13 HGB      血红 蛋 白 浓      NaN        NaN
# 60        NaN        NaN        NaN           NaN  137. 00        NaN
# 61        NaN        NaN        NaN           NaN      NaN        NaN
# 62        NaN        NaN     14 HCT        红细 胞压积      NaN        NaN
# 63        NaN        NaN        NaN           NaN   42. 00        NaN
# 64        NaN        NaN        NaN           NaN      NaN        NaN
# 65        NaN        NaN     15 MCV      平 均红 细胞体      NaN        NaN
# 66        NaN        NaN        NaN           NaN   9l, 20        NaN
#
#                     参考 Unnamed: 7     Unnamed: 8        Unnamed: 9  \
# 0                  NaN        NaN              代            项 目 名称
# 1                  NaN        NaN            NaN               NaN
# 2                  NaN        NaN            NaN               NaN
# 3       4. 00 一 10. 00     10 9/L            NaN               NaN
# 4                  NaN        NaN         16 MCH  平 均红 细\n血\n蛋 白 含
# 5                  NaN        NaN            NaN               NaN
# 6                  NaN        NaN            NaN               NaN
# 7         2.00 一 7. 00      10 9儿            NaN               NaN
# 8                  NaN        NaN        17 MCHC            平 均红细胞
# 9                  NaN        NaN            NaN            红 蛋 白浓
# 10                 NaN        NaN            NaN               NaN
# 11                 NaN        NaN            NaN               NaN
# 12         0.80 一 4 00     10「9/L            NaN               NaN
# 13                 NaN        NaN  18\nRDW-CV 红细                分布
# 14                 NaN        NaN            NaN             度 变异系
# 15                 NaN        NaN            NaN               NaN
# 16                 NaN        NaN            NaN               NaN
# 17                 NaN        NaN            NaN               NaN
# 18        0. 12 一 1.20     10 9/L             19               NaN
# 19                 NaN        NaN      RDW-SD 红细          分布\n度标 准
# 20                 NaN        NaN            NaN               NaN
# 21                 NaN        NaN            NaN               NaN
# 22                 NaN        NaN            NaN               NaN
# 23                 NaN        NaN            NaN               NaN
# 24        0. 02 一 0.50     10「9/L        20. PLT               NaN
# 25                 NaN        NaN            NaN          血小 板 数 目
# 26                 NaN        NaN            NaN               NaN
# 27                 NaN        NaN            NaN               NaN
# 28                 NaN        NaN            NaN               NaN
# 29     0\n0.10\n10「9/L        NaN            NaN               NaN
# ..                 ...        ...            ...               ...
# 37                 NaN        NaN            NaN               NaN
# 38                 NaN        NaN            NaN               NaN
# 39                 NaN        NaN            NaN               NaN
# 40  20. 00 一 40. 00\n%        NaN        23\nPCT               NaN
# 41                 NaN        NaN            NaN            血小 板压积
# 42                 NaN        NaN            NaN               NaN
# 43                 NaN        NaN            NaN               NaN
# 44        8 00 一 12.00        NaN            NaN               NaN
# 45                   首        NaN       24 P-LCC               NaN
# 46                 NaN        NaN            NaN         大血小 板 数 目
# 47                 NaN        NaN            NaN               NaN
# 48                 NaN        NaN            NaN               NaN
# 49                 NaN        NaN            NaN               NaN
# 50     0. 50一 5. 00\n%        NaN      25\nP-LCR               NaN
# 51                 NaN        NaN            NaN            大血小板比率
# 52                 NaN        NaN            NaN               NaN
# 53                 NaN        NaN            NaN               NaN
# 54                 NaN        NaN            NaN               NaN
# 55             0\nL0 %        NaN            NaN               NaN
# 56                 NaN        NaN            NaN               NaN
# 57        4. 00 一 5.50        NaN            NaN               NaN
# 58                 NaN    10 12 儿            NaN               NaN
# 59                 NaN        NaN            NaN               NaN
# 60   “120.00 一 160. 00        NaN            NaN               NaN
# 61                 NaN        g/儿            NaN               NaN
# 62                 NaN        NaN            NaN               NaN
# 63     40. 00 一 54. 00        NaN            NaN               NaN
# 64                   %        NaN            NaN               NaN
# 65                 NaN        NaN            NaN               NaN
# 66    80. 00 一 100. 00         f1            NaN               NaN
#
#    Unnamed: 10              Unnamed: 11
# 0          NaN                      NaN
# 1          结 果                       参考
# 2          NaN                      NaN
# 3          NaN                      NaN
# 4          NaN                      NaN
# 5       29. 70      27. 00 一 34. 00\npg
# 6          NaN                      NaN
# 7          NaN                      NaN
# 8          NaN                      NaN
# 9      326. 00                      NaN
# 10         NaN   320. 00 一 360. 00\ng/L
# 11         NaN                      NaN
# 12         NaN                      NaN
# 13         NaN                      NaN
# 14      13. 20                      NaN
# 15         NaN       11. 00 一 16. 00\n%
# 16         NaN                      NaN
# 17         NaN                      NaN
# 18         NaN                      NaN
# 19         NaN                      NaN
# 20      42. 30                      NaN
# 21         NaN             350“56. 00 议
# 22         NaN                      NaN
# 23         NaN                      NaN
# 24         NaN                      NaN
# 25     168. 00                      NaN
# 26         NaN   100. 00一 300. 00\n10.!
# 27         NaN                      NaN
# 28         NaN                      NaN
# 29         NaN                      NaN
# ..         ...                      ...
# 37         NaN          15. 00 一 17. 00
# 38         NaN                      NaN
# 39         NaN                      NaN
# 40         NaN                      NaN
# 41        G 37                      NaN
# 42         NaN           0 1 一 0..28\n东
# 43         NaN                      NaN
# 44         NaN                      NaN
# 45         NaN                      NaN
# 46      44. 00                      NaN
# 47         NaN  30. 00 一 90. 00\n10 9/1
# 48         NaN                      NaN
# 49         NaN                      NaN
# 50         NaN                      NaN
# 51      26. 30                      NaN
# 52         NaN        11. 00 一 45.00\n%
# 53         NaN                      NaN
# 54         NaN                      NaN
# 55         NaN                      NaN
# 56         NaN                      NaN
# 57         NaN                      NaN
# 58         NaN                      NaN
# 59         NaN                      NaN
# 60         NaN                      NaN
# 61         NaN                      NaN
# 62         NaN                      NaN
# 63         NaN                      NaN
# 64         NaN                      NaN
# 65         NaN                      NaN
# 66         NaN                      NaN
#
# [67 rows x 12 columns]
