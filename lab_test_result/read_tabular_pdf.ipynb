# %%
import os
print(os.getcwd())
# Out:
# /Users/jingjinglin/Machine_Learning/Siuvo2019SummerIntern/Tesseract-OCR/lab_test_result

# %%
import img2pdf

# %%
with open("labtest1.pdf","wb") as f:
    f.write(img2pdf.convert('labtest1_alphaoff.png'))

# %%
import camelot

# %%
tables = camelot.read_pdf('bloodtest20_1_resize1000_pdf.pdf', flavor='stream')
# Out:
# UserWarning: No tables found in table area 1 [stream.py:346]

# %%
tables.export('foo.csv', f='csv', compress=False)

# %%
tables
# Out:
# <TableList n=1>

# %%
len(tables)
# Out:
# 1

# %%
import pandas as pd

# %%
df = pd.read_csv('foo-page-1-table-1.csv', header=5)

# %%
df
# Out:
#                                            性 Unnamed: 1 Unnamed: 2  \
# 0                                计 T10071129        NaN        NaN
# 1                                    标 积 . 血        NaN        NaN
# 2                                          标        NaN        NaN
# 3                                          b        NaN        NaN
# 4                                        NaN        NaN        NaN
# 5                                        性 分        NaN        NaN
# 6                                        积 化        NaN        NaN
# 7                                17083015210        NaN        NaN
# 8                                          性        NaN        NaN
# 9                                        NaN        NaN        NaN
# 10                                         2        NaN        NaN
# 11                                 单糖E蛋二宽激醇E        NaN        NaN
# 12                              目 2017-08-30        NaN        NaN
# 13                                         葡        NaN        NaN
# 14                                     7 \n目        NaN        NaN
# 15                                       NaN        NaN        NaN
# 16                                       NaN        NaN        NaN
# 17                                        绝素        NaN        NaN
# 18                                      素嗜葡血        NaN        NaN
# 19                                         目        NaN        NaN
# 20                                         标        NaN        NaN
# 21                                     数t嗜葡固        NaN        NaN
# 22                          丁  白 脂 计 数  8.00        NaN        NaN
# 23                  3.69--9.16x10p/L  血 红  白        NaN        NaN
# 24                                       144        NaN        NaN
# 25                               113--151g/L        NaN        NaN
# 26                                       NaN        NaN        NaN
# 27                                 中 性 粒 细 胞        NaN        NaN
# 28                                     %70.1        NaN        NaN
# 29                            50.09%6--70.0%        NaN        NaN
# ..                                       ...        ...        ...
# 52                                      %0.6        NaN        NaN
# 53                                     <1.0%        NaN        NaN
# 54                       红 细 胞 分 布 宽  度 12.7        NaN        NaN
# 55                               11.6%--140%        NaN        NaN
# 56                       中 性 粒 细 胞 计  数 5.60        NaN        NaN
# 57          2.00--7.00x108/L  血 小 板 计 数  192        NaN        NaN
# 58                            101--320x108/L        NaN        NaN
# 59                             淋 巴  计 数 1.60        NaN        NaN
# 60        0.80--4.00x10/L  血 小 板 平 均 体 积 9.7        NaN        NaN
# 61                                 6.5--120f        NaN        NaN
# 62                                       NaN        NaN          度
# 63                          单 核 细 脂 计 数 0.60        NaN        NaN
# 64                     ().l2--1.oo)(1()()/Li        NaN        NaN
# 65                         酸 性 积 细 计  数 0.10        NaN        NaN
# 66                          0.02--0.50x108/L        NaN        NaN
# 67                         磷 性 粒 细 计  数 0.00        NaN        NaN
# 68                                <1.00x105L        NaN        NaN
# 69                                       NaN          目        NaN
# 70                           红 细 脂 计 数  4.48        NaN        NaN
# 71                         3.68--5.13x10L2/L        NaN        NaN
# 72                                         -        NaN        NaN
# 73                        直  间 17-08-3014.21        NaN        NaN
# 74                              17-08-301424        NaN        NaN
# 75  间  17-08-30  1L4二3l碳  8  间 .17-08-301514        NaN        NaN
# 76                                        20        NaN        NaN
# 77                                         红        NaN        NaN
# 78                               PD/  核  对 e        NaN        NaN
# 79                                       细 激        NaN        NaN
# 80                                    化 单  1        NaN        NaN
# 81                                        ()        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 